# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os

os.environ["SPOTIPY_CLIENT_ID"] = 'e643f7df10314258ad94a7f1778995f0'
os.environ["SPOTIPY_CLIENT_SECRET"] = 'b72131ac34604679880abe5d9801e677'
os.environ["SPOTIPY_REDIRECT_URI"] = 'http://localhost:/callback'

client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
#playlists = sp.user_playlists('spotify') 
playlists = sp.user_playlists('spotify')

# %%
# pulls out all the tracks in the album given album id
import time

def get_songs(playlists):
    song_ids = []
    for i in playlists:
        try:
            for j in sp.user_playlist('spotify', i)['tracks']['items']:
                song_ids.append(j['track']['id'])
                #print(j['track'])
                #print(j['track']['name'])
                file.write(j['track']['id'])
#                 print(j['track']['id'])
                file.write(',')
        except:
            pass
        time.sleep(.1)
    return song_ids

# %%
# extract details for mood based playlists from Spotify

mood_playlist_dict = {'allthefeels': '37i9dQZF1DX7gIoKXt0gmx',
                 'autumnlounge': '37i9dQZF1DWTSPqolnbHgK',
                 
                 'brainfood': '37i9dQZF1DWXLeA8Omikj7', 
                 
                 'calmvibes': '37i9dQZF1DX1s9knjP51Oa',
                 'chillingdirtroad': '37i9dQZF1DWTkxQvqMy4WW', 
                 'chilloutbrain': '37i9dQZF1DX3PIPIT6lEg5', 
                 'coffeehouse': '37i9dQZF1DX6ziVCJnEm59',
                 'confidenceboost': '37i9dQZF1DX4fpCWaHOned', 
                 'copingwithloss': '37i9dQZF1DWVxpHBekDUXK', 
                 'creativityboost': '37i9dQZF1DX56qfiUZBncF',
                 
                 'downinthedumps': '37i9dQZF1DWSqBruwoIXkA', 
                 'dreamyvibes': '37i9dQZF1DWSiZVO2J6WeI', 
                 'driftingapart': '37i9dQZF1DX38EeD6pDm10', 
                 
                 'energizinghits': '37i9dQZF1DWSWboXWl2xwB',
                  
                 'goodvibes': '37i9dQZF1DWYBO1MoTDhZI', 
                 'goosebumps': '37i9dQZF1DX8ZiJCz5fADR',
                 'hauntings': '37i9dQZF1DXa2PsvJSPnPf', 
                 'haveagreatday': '37i9dQZF1DX7KNKjOK0o75', 
                 
                 'lifesucks': '37i9dQZF1DX3YSRoSdA634',
                 'longplay': '37i9dQZF1DX3N6VbA7hVIy', 
                 'lowkey': '37i9dQZF1DX2yvmlOdMYzV', 
                 
                 'moodbooster': '37i9dQZF1DX3rxVfibe1L0',
                 'morningrhythm': '37i9dQZF1DX3ohNxI5tB79',
                 
                 'newparadigms': '37i9dQZF1DXcDTlzyXwqyu', 
                 
                 'refractions': '37i9dQZF1DWZ7mSWCFIT7v',
                 'relaxunwind': '37i9dQZF1DWU0ScTcjJBdj',
                 
                 'showersongs': '37i9dQZF1DWSqmBTGDYngZ',
                 'softmorning': '37i9dQZF1DXb5Mq0JeBbIw',
                 'stooprock': '37i9dQZF1DWYBVQgyMhM3s',
                 
                 'writersplaylist': '37i9dQZF1DWYckg2NJborB', 
                 'winteracoustic': '37i9dQZF1DWUNIrSzKgQbP',
                 
                 'youandme': '37i9dQZF1DX6mvEU1S6INL'
                }

mood_no_of_tracks = {'allthefeels': 50, 'autumnlounge': 71, 'brainfood': 65, 
                'calmvibes': 50, 'chillingdirtroad': 54, 'chilloutbrain': 119, 'coffeehouse': 97, 'confidenceboost': 50, 'copingwithloss': 89, 'creativityboost': 75, 
                'downinthedumps':49, 'dreamyvibes': 50, 'driftingapart': 50,
                'energizinghits': 26, 
                'goodvibes': 75, 'goosebumps': 51, 'hauntings': 102, 'haveagreatday': 100, 
                'lifesucks': 61, 'longplay': 29, 'lowkey': 60,
                'moodbooster': 58, 'morningrhythm': 50, 'newparadigms': 50,
                'refractions': 50, 'relaxunwind':75, 
                'showersongs': 58, 'softmorning': 58, 'stooprock': 44,
                 'winteracoustic': 86, 
                'writersplaylist': 97, 'youandme': 105
               }
# 32 playlists, 2112 songs

for key in mood_playlist_dict.keys():
    mood_playlists=[mood_playlist_dict[key]]
    file = open('/Users/feelharmonic/Dropbox/Insight2018/SaReGaMood/SpotifyMoodPlaylistData/playlist_trackIds/'+key+'.txt', 'w') 
    songs = get_songs(mood_playlists)
    file.close()

# %%
# Analytics on the MOOD data 
# based on the features: valence, energy

import pandas as pd

for key in mood_playlist_dict.keys():
    
    mood_valence_avg = 0.0
    mood_energy_avg = 0.0
#     tempo_avg = 0.0
    
    data = pd.read_csv('/Users/feelharmonic/Dropbox/Insight2018/SaReGaMood/SpotifyMoodPlaylistData/playlist_data/Data_'+key+'.txt', header = None, skiprows=1, usecols=[0])
    #print(data)
    for i in range(0, len(data)):
        myrow = data.iloc[i][0]
        if "valence" in myrow:
            start = myrow.find(':') + 2
            end = myrow.find('.') + 4
            mood_valence_avg = mood_valence_avg + float(myrow[start:end])
            #print(myrow[start:end])
            
        if "energy" in myrow:
            start = myrow.find(':') + 2
            end = myrow.find('.') + 4
            mood_energy_avg = mood_energy_avg + float(myrow[start:end])
            #print(myrow[start:end])
            
#         if "tempo" in myrow:
#             start = myrow.find(':') + 2
#             end = myrow.find('.') + 4
#             tempo_avg = tempo_avg + float(myrow[start:end])
#             #print(myrow[start:end])

    
    mood_valence_avg = valence_avg/no_of_tracks[key]
#     tempo_avg   = tempo_avg/no_of_tracks[key]
    mood_energy_avg  = energy_avg/no_of_tracks[key]
#     print(valence_avg, tempo_avg, energy_avg)
    print(mood_valence_avg, mood_energy_avg)
# Out:
# 0.3310799999999999 0.4331400000000001
# 0.22973239436619713 0.3319014084507042
# 0.20093846153846154 0.5780615384615383
# 0.19858000000000003 0.09286000000000001
# 0.6469814814814816 0.7579444444444443
# 0.13939495798319332 0.3440672268907563
# 0.3245154639175256 0.291
# 0.52852 0.70792
# 0.29368539325842696 0.45907865168539325
# 0.33581333333333335 0.5228266666666666
# 0.2882244897959184 0.4365510204081633
# 0.07877999999999999 0.10561999999999998
# 0.3095999999999999 0.40562
# 0.5771538461538461 0.7040769230769232
# 0.46796000000000004 0.6698399999999997
# 0.18733333333333335 0.9294509803921569
# 0.2289803921568627 0.3669411764705882
# 0.7509999999999999 0.7056699999999999
# 0.2843770491803279 0.49383606557377047
# 0.3906896551724138 0.6437586206896553
# 0.3628166666666667 0.48175
# 0.47806896551724143 0.6874310344827588
# 0.59788 0.6587999999999999
# 0.14852000000000004 0.23348000000000002
# 0.29750000000000004 0.53084
# 0.2846266666666665 0.43113333333333337
# ...

# %%
# extract details for indian classical playlists from Spotify
# adding an extra 'p' in front of playlist name
# search as "https://open.spotify.com/user/<username>/playlist/<playlist_id>"

ind_playlist_dict = {'spotify': '37i9dQZF1DXbw9rGYPXetO', 'angie0120': '5PJ6yB62lTOLnjjA2oV1CU',
                     '127110711': '6uXfPY3H1ZBI4er2SC0Gvh',
                     '225mpkskelgbn63oztuyaa2pq': '1458RT24gmXhUUdGH6Amgv', '_aj22': '42Sf5vD0N768X1QTOdyzxT',
                     'gian.surdhar': '5INuFdXcuDH7WSvZh4rSHL', '122053317': '5XWDoDG6YqXG2C2vNUYMW5',
                     'sanyam': '0NbcBMmsImsFxnIbteSi7G',
                     'vishalkthacker': '4MQ0pu1jA5uRUHdjV7VMtp', 'kirtisaran': '4T1o42qQK2O4BXcGtneLkQ',
                     'harmeet-gb': '4tjbOUdTpURiS1GRKbAQKR', 'devadhyanam': '1lBntQ1Y01NsjWcRTEliZw',
                     '21zk53ftztm72uwmy2gbu3iaa': '6Jg3KPu3ajs8tMHWb6uJ7l', '12158508968': '0BWYh39KiAcNgxrKcqnfjT',
                     '1229577022': '5OATRZm63NZpRCNtVbLCQd', '1224811690': '2CbCJFK4djGUVYySN7yAE2',
                     '0meglj9g4m5y7r9drw1y53qcx': '3Lo8Z7G0k6pTFTZuyFDkag', '1245892277': '6s01P2BpusinOKYQzh0AyV',
                     'raveesh.shenoy': '4xHEuGI2neODOxukPRR5xS', '12159416648': '6TjDEX8eLvDvwx996sJ2QH', 
                     'tournolive': '0uvmD4sNB4RzrxouV8qZ4l', 'stevengelberg': '7KMTOeSTcHQeb4Qikb9uyc',
                     
                     
                     '12136805395': '1cN7lUMrFMC954KrKzk5mV', 
                     'matthewhepburn': '4cyn2drJ49NF5uM2YtwdRS', 
                     'gabesoileau': '2l9z9voOFbuNmlJoC0vdDH', 
                     '22mjvsadmqh4kb3k2m5u42ldy': '6oEzc64o3RNofCdnPUzLvX', '1168110925': '2Rc5zgfbSAgDkU0irs6Yy4',
                     '1148584027': '6tbZqAkoXxCO2cTtqeC5VA', 
                     '1276764805': '6MqFiKDt3ZJXNjY9GSXXFx', 
                     '12141976702': '1h65hClFfGyFf3cLJJwKVi', 'gabesoileau': '7fT2mwKBuMx4eZKInfeCXL',
                    'buddhafabber': '66Szike9gNgaPYGmgOzmNF',
                     'chloezadeh': '71vcTSb6j2vGZ04jXKGpUc', '121142730': '3frGkez4486ROIIaoDrEbd', 
                     'harsh91': '5hCooo2wJSCqPc12gLaJMr',
                     'vinkamath': '31VrPlak12Q0v8VWfLOROZ', 
                     'hsakaleog': '35zbgOHmjJnEIqyhE7c0Vt', 'dominia30': '5JlxLto7U0o3x7Ufu4Hahq',  
                     'tccdayton': '1J5ikzyGs6a4Qgb3RFMfHJ'
                    }
    
ind_no_of_tracks_dict = {'spotify': 20, 'angie0120': 46,  '127110711': 20, 
                         '225mpkskelgbn63oztuyaa2pq': 5, '_aj22': 12, 'gian.surdhar': 12, '122053317': 9,
                          'sanyam': 77, 'vishalkthacker': 84, 'kirtisaran': 12, 'harmeet-gb': 23,
                         'devadhyanam': 23, '21zk53ftztm72uwmy2gbu3iaa': 7, '12158508968': 91, 
                         '1229577022': 24, '1224811690': 14, '0meglj9g4m5y7r9drw1y53qcx': 19,
                         '1245892277': 23, 'raveesh.shenoy': 31, '12159416648': 51, 'tournolive': 8, 
                         'stevengelberg': 70, 
                         
                         
                         '12136805395': 100, 'matthewhepburn': 100, 
                         'gabesoileau': 100,
                         '22mjvsadmqh4kb3k2m5u42ldy': 100, '1168110925': 100, '1148584027': 100, 
                         '1276764805': 100,  '12141976702': 100,
                         'gabesoileau': 100, 'buddhafabber': 100, 
                         'chloezadeh': 100, 
                         '121142730': 100, 'harsh91': 100, 'vinkamath': 100,
                        'hsakaleog': 100,
                         'dominia30': 100,
                         'tccdayton': 100
                        }

# for playlists > 100 songs (the lower set of rows) play with offset here https://developer.spotify.com/web-api/console/get-playlist-tracks/#complete
# '12141976702': 3209', 'gabesoileau': 200, 'buddhafabber': 352', 'chloezadeh': 214, '121142730': 287, 'harsh91': 288, 'vinkamath': 481', 'hsakaleog': 169, 'dominia30': 246, 'tccdayton': 228,'thesoundsofspotify': 368

# for key in ind_playlist_dict.keys():
#     ind_playlists=[ind_playlist_dict[key]]
#     file = open(key+'.txt', 'w') 
#     songs = get_songs(ind_playlists)
#     file.close()

# %%
#Plotting stuff

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

valence_avg = [0.20093846153846154, 0.3310799999999999, 0.46796000000000004, 0.47806896551724143,
               0.6469814814814816, 0.3174069767441862, 0.07877999999999999, 0.7019827586206897, 0.7509999999999999,
               0.3245154639175256, 0.2846266666666665, 0.13939495798319332 ]
energy_avg = [0.5780615384615383, 0.4331400000000001, 0.6698399999999997, 0.6874310344827588,
              0.7579444444444443, 0.3223255813953489, 0.10561999999999998, 0.7402068965517243,
              0.7056699999999999, 0.291, 0.43113333333333337, 0.3440672268907563]
tempo_avg = [124.06412307692305, 110.65663999999998, 114.64854666666663, 113.36515517241376, 
             125.53540740740739 , 113.30452325581392, 92.88250000000002, 118.22832758620686, 117.53338, 
             113.14569072164952, 118.64045333333338, 97.27849579831936]

# # plt.title('Tempo-Valence')
# # Set x-axis label
# plt.xlabel('Valence')
# # Set y-axis label
# plt.ylabel('Tempo')
# ax = sns.regplot(x=valence_avg, y=tempo_avg, color="g")

name_string = ['brainfood', 'allthefeels', 'goodvibes', 'moodbooster', 'chillingdirtroad', 'winteracoustic',
                 'dreamyvibes', 'showersongs', 'haveagreatday', 'coffeehouse', 'relaxunwind', 'chilloutbrain'];

# n=[58,651,393,203,123]

fig, ax = plt.subplots()

for i, txt in enumerate(name_string):
    ax.annotate(txt, (valence_avg[i],tempo_avg[i]))
    
# plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.gca(projection='3d')

# Demo 1: zdir
zdirs = (None, 'x', 'y', 'z', (1, 1, 0), (1, 1, 1))
xs = [0.20093846153846154, 0.3310799999999999, 0.46796000000000004, 0.47806896551724143,
               0.6469814814814816, 0.3174069767441862, 0.07877999999999999, 0.7019827586206897, 0.7509999999999999,
               0.3245154639175256, 0.2846266666666665, 0.13939495798319332 ] #valence
ys = [0.5780615384615383, 0.4331400000000001, 0.6698399999999997, 0.6874310344827588,
              0.7579444444444443, 0.3223255813953489, 0.10561999999999998, 0.7402068965517243,
              0.7056699999999999, 0.291, 0.43113333333333337, 0.3440672268907563] #energy
zs = [124.06412307692305, 110.65663999999998, 114.64854666666663, 113.36515517241376, 
             125.53540740740739 , 113.30452325581392, 92.88250000000002, 118.22832758620686, 117.53338, 
             113.14569072164952, 118.64045333333338, 97.27849579831936] #tempo


for zdir, x, y, z in zip(zdirs, xs, ys, zs):
#     label = '(%d, %d, %d), dir=%s' % (x, y, z, zdir)
    
    ax.text(x, y, z, label, zdir)

# Demo 2: color
ax.text(9, 0, 0, "red", color='red')

# Demo 3: text2D
# Placement 0, 0 would be the bottom left, 1, 1 would be the top right.
ax.text2D(0.05, 0.95, "2D Text", transform=ax.transAxes)

# Tweaking display region and labels
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 150)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

plt.show()

# %%
# old code

# # get categories
# def get_categories():
#     category_ids = []
#     for i in sp.categories(limit = 50)['categories']['items']:
#         category_ids.append(i.get('id'))
#     return category_ids
# print('----')

# # get playlists from list of categories
# def get_playlists(categories):
#     playlist_ids = []
#     for i in categories:
#         for j in sp.category_playlists(i, limit = 50)['playlists']['items']:
#             playlist_ids.append(j.get('id'))
#             print(j)
#     return playlist_ids
# print('----')



# categories = get_categories()
# playlists = get_playlists(categories)
